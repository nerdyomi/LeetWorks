# %%
class Solution(object):
    def addBinary(self, a, b):
        """
        :type a: str
        :type b: str
        :rtype: str
        """
        x=int(a,2)+int(b,2)
        return bin(x)[2:]

# %%
a=Solution()
a.addBinary("11","1")
# Out:
# '100'
