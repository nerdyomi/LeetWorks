# %%
class Solution(object):
    def hammingWeight(self, n):
        """
        :type n: int
        :rtype: int
        """
        x=bin(n)
        return (x[2:].count("1"))

# %%
a=Solution()
a.hammingWeight(11)
# Out:
# 3
